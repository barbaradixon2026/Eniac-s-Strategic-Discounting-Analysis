# %% [markdown]
# # Quality Assessment
# Now it's your turn. Follow the steps on the platform and use what you've learnt to see how reliable the data is.

# %%
import pandas as pd

# %% [markdown]
# Load our cleaned DataFrames

# %%
# orders_cl.csv
url = "https://drive.google.com/file/d/1Tla62vfu__kCqvgypZyVt2S9VuC016yH/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders_cl = pd.read_csv(path, parse_dates=[1])

# orderlines_cl.csv
url = "https://drive.google.com/file/d/1OhtkQS2fwOYdzfd-qPh7im35iLc-L9TA/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines_cl = pd.read_csv(path, parse_dates=[6])

# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %% [markdown]
# Let's create a copy of our DataFrames, to make sure any of our changes won't affect the original DataFrame. We'll also change the DataFrames from `_cl` to `_qu`, so we can distinguish between the data that has been cleaned, and that which has been quality controlled.

# %%
orders_qu = orders_cl.copy()

# %%
orderlines_qu = orderlines_cl.copy()

# %%
products_qu = products_cl.copy()

# %% [markdown]
# ## 1.&nbsp; Define Pandas display format

# %%
pd.set_option("display.float_format", lambda x: "%.2f" % x)
pd.set_option("display.max_rows", 1000)

# %% [markdown]
# ## 2.&nbsp; Exclude unwanted orders

# %% [markdown]
# ### `orders` - Keep only orders with the state you want to work with
# No `shopping cart`, `cancelled` etc...

# %%
orders_qu["state"].unique()
# Out:
# array(['Cancelled', 'Completed', 'Pending', 'Shopping Basket',
#        'Place Order'], dtype=object)

# %%
orders_qu.head()
# Out:
#    order_id        created_date  total_paid      state
# 0    241319 2017-01-02 13:35:40       44.99  Cancelled
# 1    241423 2017-11-06 13:10:02      136.15  Completed
# 2    242832 2017-12-31 17:40:03       15.76  Completed
# 3    243330 2017-02-16 10:59:38       84.98  Completed
# 4    243784 2017-11-24 13:35:19      157.86  Cancelled

# %% [markdown]
# Let's look at the make up of `state`.

# %%
orders_qu["state"].value_counts()
# Out:
# state
# Shopping Basket    117809
# Completed           46605
# Place Order         40883
# Pending             14374
# Cancelled            7233
# Name: count, dtype: int64

# %% [markdown]
# Seems like an overwhelming amount of the orders are left in the shopping basket - something we'll have to analyse another time. For this task we're interested in only `completed` orders, so let's filter our DataFrame.

# %%
# keep only completed orders
orders_qu = orders_qu.loc[orders_qu["state"] == "Completed", :]

# %%
# orders_qu = orders_qu.loc[orders_qu["state"].isin(["Completed", "Pending"]), :]

# %%
orders_qu.shape
# Out:
# (46605, 4)

# %% [markdown]
# ### Keep only the orders that are present in both `orders` and `orderlines`

# %% [markdown]
# Let's begin by looking if there's a big difference between the amount of orders present in `orders` and `orderlines`.

# %%
orders_qu["order_id"].nunique()
# Out:
# 46605

# %%
orderlines_qu["id_order"].nunique()
# Out:
# 170213

# %% [markdown]
# What a huge difference! We want to make sure that every order_id in `orders` also exists in `orderlines` and vice versa.
#
# Hence we'll perform an inner merge on the two tables using the `order_id` & `id_order`. This will then keep only the `order_id`'s that are present in both tables, which will then help us filter our `_qu` DataFrames once again.

# %%
orders_orderlines = orders_qu.merge(orderlines_qu, how="inner", left_on="order_id", right_on="id_order")

# %%
# orders_orderlines

# %%
# order_ids that are in both tables
order_ids = orders_orderlines["order_id"].sort_values().unique()

# %%
order_ids
# Out:
# array([241423, 242832, 243330, ..., 527074, 527096, 527112])

# %%
# keep those ids in orders
orders_qu = orders_qu.loc[orders_qu["order_id"].isin(order_ids), :]

# keep those ids in orderlines
orderlines_qu = orderlines_qu.loc[orderlines_qu["id_order"].isin(order_ids), :]

# %%
orders_qu.shape
# Out:
# (43064, 4)

# %% [markdown]
# Let's have a quick check to make sure we're filtering both DataFrames the same. They should both contain the same number of unique `order_id`'s.

# %%
orders_qu["order_id"].nunique(), orderlines_qu["id_order"].nunique()
# Out:
# (43064, 43064)

# %% [markdown]
# #### Alternative to merge

# %%
# alternatively, you can use sets (do not allow for duplicates) and the method .intersection()
o_order_ids = set(orders_qu["order_id"])
ol_id_orders = set(orderlines_qu["id_order"])
common_order_ids = o_order_ids.intersection(ol_id_orders)

orders_qu = orders_qu.loc[orders_qu["order_id"].isin(common_order_ids), :]
orderlines_qu = orderlines_qu.loc[orderlines_qu["id_order"].isin(common_order_ids), :]

# %%
len(common_order_ids)
# Out:
# 43064

# %%
# backcheck
((orders_qu["order_id"].sort_values().tolist()) == (orderlines_qu["id_order"].sort_values().unique())).sum()
# set(orders_qu["order_id"]) == set(orderlines_qu["id_order"])
# Out:
# np.int64(43064)

# %%
(orders_qu["order_id"].sort_values().tolist() == orderlines_qu["id_order"].sort_values().unique()).sum()
# Out:
# np.int64(43064)

# %% [markdown]
# ## 3.&nbsp; Exclude orders with unknown products

# %% [markdown]
# Let's start by investigating `orderlines` and `products`. We want to make sure that every product in `orderlines` has a matching entry in `products`. All orders with a missing product need to be removed from both `orderlines` and `orders`.
#
# A left-join can help us here:
#
# Joining `orderlines` left on `products` will keep all orderlines, and add the information of `products` on the matching skus. If an sku has been sold in `orderlines`, but the sku does not have an entry in `products` then the product_name will be empty.

# %%
orderlines_products = orderlines_qu.merge(products_qu, how="left", on = "sku")[["id_order","sku","name" ]]
orderlines_products.sample(10)
# Out:
#        id_order        sku                                               name
# 12185    354044    LOG0178  Multi-Device Logitech K480 Keyboard for iPad /...
# 10632    348248  CRU0043-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...
# 28060    415767    SAM0120       LS22F352FHU Samsung Monitor 22 "FHD HDMI VGA
# 31467    426883    SAT0054     Satechi Hub Multiport USB-C 4K HDMI Space Gray
# 32117    430724    APP2493                                                NaN
# 40685    464247    WAC0046                     Intuos Wacom stylus ArtPen 5/4
# 16199    372684    MOS0154  Moshi Mini DisplayPort to HDMI Adapter compati...
# 47121    487506    JBL0149  JBL JR300 BT Bluetooth Headset Diadema Rosa Ch...
# 382      300720    OTT0143  Otterbox Clearly Protected gel Case iPhone 6 /...
# 35369    441985    NTE0069         NewerTech Lightning to USB Cable 50cm Blue

# %% [markdown]
# We can count how many missing products we have.

# %%
orderlines_products["name"].isna().value_counts()
# Out:
# name
# False    55320
# True      1394
# Name: count, dtype: int64

# %% [markdown]
# Looks like the vast majority of products are known.
#
# We can't simply delete the rows containing unknown products. We need to remove the entirety of any order that contains an unknown product to keep a consistent and coherent dataset.

# %%
orders_to_delete = orderlines_products.loc[orderlines_products["name"].isna(), "id_order"].unique()
orders_to_delete
# Out:
# array([299638, 299706, 299712, ..., 526106, 526122, 526363])

# %% [markdown]
# Keep only orders in `orders` and `orderlines`, that are not in this list of corrupted orders.

# %%
orders_qu = orders_qu.loc[~orders_qu["order_id"].isin(orders_to_delete),:]

# %%
orderlines_qu = orderlines_qu.loc[~orderlines_qu["id_order"].isin(orders_to_delete),:]

# %% [markdown]
# Let's have a quick check to make sure we're filtering both DataFrames the same. They should both contain the same number of unique `order_id`'s.

# %%
orders_qu["order_id"].nunique(), orderlines_qu["id_order"].nunique()
# Out:
# (41701, 41701)

# %% [markdown]
# ## 4.&nbsp; Explore the revenue from different tables

# %% [markdown]
# In a consistent and coherent dataset the value of an order should roughly match the sum of all items bought on that order. Let's investigate...

# %%
orderlines_qu_copy = orderlines_qu.copy()

# %%
orders_qu_copy = orders_qu.copy()

# %% [markdown]
# #### Step 1:
# Create the `unit_price_total` as `orderlines.unit_price` * `orderlines.product_quantity`

# %%
orderlines_qu_copy["unit_price_total"] = orderlines_qu_copy["product_quantity"] * orderlines_qu_copy["unit_price"]

# %%
orderlines_qu_copy.tail(10)
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 215873  1649440    527035           0                 1  APP0498       23.00
# 215874  1649441    527034           0                 1  APP0927       13.99
# 215876  1649446    527042           0                 1  APP0927       13.99
# 215877  1649447    527035           0                 1  APP0698        9.99
# 215886  1649468    525664           0                 1  TUC0336        7.93
# 215889  1649474    525664           0                 1  TUC0207       16.52
# 215906  1649512    527070           0                 2  APP0698        9.99
# 215911  1649522    527074           0                 2  APP0698        9.99
# 215932  1649565    527096           0                 3  APP0698        9.99
# 215949  1649593    527112           0                 1  APP0698        9.99
#
#                       date  unit_price_total
# 215873 2018-03-14 11:41:55             23.00
# 215874 2018-03-14 11:42:01             13.99
# 215876 2018-03-14 11:42:38             13.99
# 215877 2018-03-14 11:42:41              9.99
# 215886 2018-03-14 11:43:59              7.93
# 215889 2018-03-14 11:45:05             16.52
# 215906 2018-03-14 11:49:01             19.98
# 215911 2018-03-14 11:49:36             19.98
# 215932 2018-03-14 11:54:35             29.97
# 215949 2018-03-14 11:58:13              9.99

# %% [markdown]
# #### Step 2:
# Group by `id_order`, summarising by the sum of `unit_price_total`

# %%
orderlines_order_ids = orderlines_qu_copy.groupby("id_order", as_index=False)["unit_price_total"].sum()
# as_index=False changes the return so that the groupedby column remains a column (not the index)

# %%
orderlines_order_ids
# Out:
#        id_order  unit_price_total
# 0        241423            129.16
# 1        242832             10.77
# 2        243330             77.99
# 3        245275            149.00
# 4        245595            105.98
# ...         ...               ...
# 41696    527042             13.99
# 41697    527070             19.98
# 41698    527074             19.98
# 41699    527096             29.97
# 41700    527112              9.99
#
# [41701 rows x 2 columns]

# %% [markdown]
# ### What is the average difference between `total_paid` and `unit_price_total`?

# %% [markdown]
# Let's merge our grouped `orderlines` table with the `orders` table, so we can calculate the differences in prices.

# %%
diff_df = orders_qu_copy.merge(orderlines_order_ids, left_on="order_id", right_on="id_order")

# %%
diff_df["difference"] = diff_df["total_paid"] - diff_df["unit_price_total"]
diff_df.head(10)
# Out:
#    order_id        created_date  total_paid      state  id_order  \
# 0    241423 2017-11-06 13:10:02      136.15  Completed    241423
# 1    242832 2017-12-31 17:40:03       15.76  Completed    242832
# 2    243330 2017-02-16 10:59:38       84.98  Completed    243330
# 3    245275 2017-06-28 11:35:37      149.00  Completed    245275
# 4    245595 2017-01-21 12:52:47      112.97  Completed    245595
# 5    246405 2017-11-24 10:01:27      407.96  Completed    246405
# 6    247524 2018-01-09 14:21:34      167.98  Completed    247524
# 7    247643 2017-05-26 11:50:35      153.54  Completed    247643
# 8    250275 2017-11-19 22:34:54       54.99  Completed    250275
# 9    251302 2017-05-10 12:27:33      140.99  Completed    251302
#
#    unit_price_total  difference
# 0            129.16        6.99
# 1             10.77        4.99
# 2             77.99        6.99
# 3            149.00        0.00
# 4            105.98        6.99
# 5            275.75      132.21
# 6            162.99        4.99
# 7            153.54        0.00
# 8             51.00        3.99
# 9            140.99        0.00

# %% [markdown]
# Now that we know the difference for each order, we can compute the average.

# %%
diff_df.difference.mean().round(2)
# Out:
# np.float64(4.47)

# %% [markdown]
# ### What is the distribution of these differences?

# %%
diff_df["difference"].hist(bins= 50, figsize=(8,6));

# %% [markdown]
# Looking at the spread of the data above, some of the difference must be due to corruption. Let's use `.describe()` to investigate the distribution further.

# %%
diff_df["difference"].describe()
# Out:
# count   41701.00
# mean        4.47
# std        26.05
# min      -165.00
# 25%         0.00
# 50%         4.99
# 75%         6.99
# max      3984.99
# Name: difference, dtype: float64

# %% [markdown]
# We can see from the our quartiles (0.00, 4.99, 6.99) that most of our data fits an expected pattern - free, 4.99, and 6.99 all seem like reasonable prices to assume as postage. However, look at the min and the max values, -165.00 and 3984.99, this can only occur due to corrupted data.

# %% [markdown]
# ### Can all the differences be explained by shipping costs? If not, what are other plausible explanations?

# %% [markdown]
# What reasons have you come up with to explain the difference?

# %% [markdown]
# ### If there are differences that you can’t explain: what should you do with these orders?
# There's a rule of thumb, that anything:
# + lower than the 25% quartile - (1.5 x interquartile range), or
# + higher than the 75% quartile + (1.5 x interquartile range)
#
# is an outlier. Let's use this rule to try and exclude any corrupted data.

# %%
# We know this rule from the boxplot
import matplotlib.pyplot as plt

ax = diff_df.boxplot("difference");
ax.set_ylim(-30, +30)
plt.show()

# %%
# calculate the quartiles
Q1 = diff_df["difference"].quantile(0.25)
Q3 = diff_df["difference"].quantile(0.75)

Q1, Q3
# Out:
# (np.float64(0.0), np.float64(6.989999999999981))

# %%
# calculate the interquartile range
IQR = Q3-Q1
IQR
# Out:
# np.float64(6.989999999999981)

# %%
# lower boundary
Q1 - 1.5*IQR
# Out:
# np.float64(-10.484999999999971)

# %%
# upper boundary
Q3 + 1.5*IQR
# Out:
# np.float64(17.47499999999995)

# %%
# filter the DataFrame to include only "non-outliers"
diff_no_outliers_df = diff_df.loc[
    (diff_df["difference"] >= (Q1 - 1.5*IQR))
    &
    (diff_df["difference"] <= (Q3 + 1.5*IQR))
    ,
    :]

# %% [markdown]
# Let's look at the distribution again to see the effect of removing the outliers.

# %%
diff_no_outliers_df["difference"].hist(bins= 50, figsize=(8,6));

# %%
diff_no_outliers_df.boxplot("difference")
# Out:
# <Axes: >

# %% [markdown]
# This looks much more like what we would expect: a small difference, but nothing extreme.
#
# Now we need to remove these orders with extreme differences from our `orders_lines_merged` DataFrame.

# %%
normal_diff_list = diff_no_outliers_df["order_id"]

# %%
orders_qu = orders_qu.loc[orders_qu["order_id"].isin(normal_diff_list), :]
orderlines_qu = orderlines_qu.loc[orderlines_qu["id_order"].isin(normal_diff_list), :]

# %%
orders_qu["order_id"].nunique(), orderlines_qu["id_order"].nunique()
# Out:
# (40985, 40985)

# %% [markdown]
# Let's hear your thoughts about what you discovered.

# %% [markdown]
# ##### Explorations on negative discounts

# %%
merged_df = orderlines_qu.merge(products_qu, on ="sku")
merged_df = merged_df.loc[:, ["id_order", "name", "desc", "sku", "price", "unit_price"]]

# %%
merged_df["difference_aka_discount"] = merged_df["price"] - merged_df["unit_price"]

# %%
merged_df["difference_aka_discount_pct"] = merged_df["difference_aka_discount"] / merged_df["price"] * 100

# %%
merged_df
# Out:
#        id_order                                               name  \
# 0        299545  OWC In-line Digital Temperature Sensor Kit HDD...
# 1        299546               iOttie Easy View 2 Car Black Support
# 2        295347  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3        299556                 (Open) Crucial 240GB SSD 7mm BX200
# 4        299561                 Pebble Smartwatch Time Steel Black
# ...         ...                                                ...
# 53226    527035  Apple Lightning Cable Connector to USB 1m Whit...
# 53227    527070  Apple Lightning Cable Connector to USB 1m Whit...
# 53228    527074  Apple Lightning Cable Connector to USB 1m Whit...
# 53229    527096  Apple Lightning Cable Connector to USB 1m Whit...
# 53230    527112  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc        sku  price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...    OWC0100  60.99
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...    IOT0014  22.95
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...    APP0700  89.00
# 3      SSD hard drive and high-speed performance with...  CRU0039-A  76.99
# 4      Bluetooth Smart Watch with steel case leather ...    PEB0015 299.99
# ...                                                  ...        ...    ...
# 53226  Apple Lightning USB Cable 1 meter to charge an...    APP0698  25.00
# 53227  Apple Lightning USB Cable 1 meter to charge an...    APP0698  25.00
# 53228  Apple Lightning USB Cable 1 meter to charge an...    APP0698  25.00
# 53229  Apple Lightning USB Cable 1 meter to charge an...    APP0698  25.00
# 53230  Apple Lightning USB Cable 1 meter to charge an...    APP0698  25.00
#
#        unit_price  difference_aka_discount  difference_aka_discount_pct
# 0           47.49                    13.50                        22.13
# 1           18.99                     3.96                        17.25
# 2           72.19                    16.81                        18.89
# 3           60.90                    16.09                        20.90
# 4          142.49                   157.50                        52.50
# ...           ...                      ...                          ...
# 53226        9.99                    15.01                        60.04
# 53227        9.99                    15.01                        60.04
# 53228        9.99                    15.01                        60.04
# 53229        9.99                    15.01                        60.04
# 53230        9.99                    15.01                        60.04
#
# [53231 rows x 8 columns]

# %%
merged_df['difference_aka_discount_pct'].describe()
# Out:
# count   53231.00
# mean       21.38
# std        18.15
# min      -212.27
# 25%         9.09
# 50%        17.65
# 75%        28.59
# max        97.14
# Name: difference_aka_discount_pct, dtype: float64

# %%
merged_df.loc[merged_df['difference_aka_discount_pct'] < 0].nsmallest(20, columns="difference_aka_discount_pct")
# Out:
#        id_order                                               name  \
# 10025    347233             iFixit piece Earpiece Speaker iPhone 6
# 17256    379925             iFixit piece Earpiece Speaker iPhone 6
# 19633    388586             iFixit piece Earpiece Speaker iPhone 6
# 18040    382838           Prynt White iPhone Case Portable Printer
# 7613     324159  Mac memory Kingston 16GB (2x8GB) SO-DIMM DDR3å...
# 18858    385352                   Full screen repair iPhone 7 Plus
# 35641    446921                   Full screen repair iPhone 7 Plus
# 7243     322961  Mac memory Kingston 16GB (2x8GB) SO-DIMM DDR3å...
# 22145    399064                       battery repair iPhone 6 Plus
# 272      300497                        Full screen repair iPhone 5
# 5790     317872  Mac memory Kingston 16GB (2x8GB) SO-DIMM DDR3å...
# 10790    351779  Mac memory Kingston 16GB (2x8GB)-DIMM DDR3 186...
# 12173    357917  Mac memory Kingston 16GB (2x8GB)-DIMM DDR3 186...
# 12870    361081  Mac memory Kingston 16GB (2x8GB)-DIMM DDR3 186...
# 10362    349872  Mac memory Kingston 32GB (4x8GB) SO-DIMM DDR3 ...
# 12599    360093  Mac memory Kingston 32GB (4x8GB) SO-DIMM DDR3 ...
# 9003     345205                  Full screen repair iPhone 6s Plus
# 18714    384829                  Full screen repair iPhone 6s Plus
# 8365     326888  Mac memory Kingston 16GB (2x8GB) SO-DIMM DDR3å...
# 34841    448191                   Full screen repair iPhone 7 Plus
#
#                                                     desc        sku  price  \
# 10025              Handset internal speaker for iPhone 6    IFX0074   7.99
# 17256              Handset internal speaker for iPhone 6    IFX0074   7.99
# 19633              Handset internal speaker for iPhone 6    IFX0074   7.99
# 18040  Portable hard case with 10 sheets of printer i...    PRY0008  74.99
# 7613   RAM 16GB (2x8GB) iMac (2010/2011) Mac mini (20...  KIN0149-2 105.98
# 18858  Repair service including parts and labor for i...    REP0396 119.99
# 35641  Repair service including parts and labor for i...    REP0396 119.99
# 7243   RAM 16GB (2x8GB) iMac (2010/2011) Mac mini (20...  KIN0149-2 105.98
# 22145  Repair service including parts and labor for i...    REP0301  39.99
# 272    Repair service including parts and labor for i...    REP0134  59.99
# 5790   RAM 16GB (2x8GB) iMac (2010/2011) Mac mini (20...  KIN0149-2 105.98
# 10790  Mac memory Kingston 16GB (2x8GB) HyperX DDR3 S...  KIN0125-2 119.98
# 12173  Mac memory Kingston 16GB (2x8GB) HyperX DDR3 S...  KIN0125-2 119.98
# 12870  Mac memory Kingston 16GB (2x8GB) HyperX DDR3 S...  KIN0125-2 119.98
# 10362  Mac memory Kingston 32GB (4x8GB) HyperX DDR3 S...  KIN0125-4 239.97
# 12599  Mac memory Kingston 32GB (4x8GB) HyperX DDR3 S...  KIN0125-4 239.97
# 9003   Repair service including parts and labor for i...    REP0323 109.99
# 18714  Repair service including parts and labor for i...    REP0323 109.99
# 8365   RAM 16GB (2x8GB) iMac (2010/2011) Mac mini (20...  KIN0149-2 105.98
# 34841  Repair service including parts and labor for i...    REP0396 119.99
#
#        unit_price  difference_aka_discount  difference_aka_discount_pct
# 10025       24.95                   -16.96                      -212.27
# 17256       24.95                   -16.96                      -212.27
# 19633       24.95                   -16.96                      -212.27
# 18040      135.99                   -61.00                       -81.34
# 7613       170.99                   -65.01                       -61.34
# 18858      189.99                   -70.00                       -58.34
# 35641      189.99                   -70.00                       -58.34
# 7243       163.99                   -58.01                       -54.74
# 22145       59.99                   -20.00                       -50.01
# 272         89.99                   -30.00                       -50.01
# 5790       155.79                   -49.81                       -47.00
# 10790      174.99                   -55.01                       -45.85
# 12173      174.99                   -55.01                       -45.85
# 12870      174.99                   -55.01                       -45.85
# 10362      349.99                  -110.02                       -45.85
# 12599      349.99                  -110.02                       -45.85
# 9003       159.99                   -50.00                       -45.46
# 18714      159.99                   -50.00                       -45.46
# 8365       153.89                   -47.91                       -45.21
# 34841      170.99                   -51.00                       -42.50

# %%
merged_df.loc[merged_df['difference_aka_discount_pct'] <0, ["id_order", "difference_aka_discount_pct"]].nsmallest(3, columns="difference_aka_discount_pct")#["id_order"]
# Out:
#        id_order  difference_aka_discount_pct
# 10025    347233                      -212.27
# 17256    379925                      -212.27
# 19633    388586                      -212.27

# %%
merged_df.loc[merged_df['difference_aka_discount_pct'] < 0, "difference_aka_discount_pct"] = 0

# %%
merged_df['difference_aka_discount_pct'].describe()
# Out:
# count   53231.00
# mean       21.57
# std        17.74
# min         0.00
# 25%         9.09
# 50%        17.65
# 75%        28.59
# max        97.14
# Name: difference_aka_discount_pct, dtype: float64

# %% [markdown]
# ## 5.&nbsp; Become confident about your dataset

# %% [markdown]
# Let's not forget to download our quality controlled DataFrames

# %%
# from google.colab import files

# orders_qu.to_csv("orders_qu.csv", index=False)
# files.download("orders_qu.csv")

# orderlines_qu.to_csv("orderlines_qu.csv", index=False)
# files.download("orderlines_qu.csv")
